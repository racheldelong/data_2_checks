# %%
import pandas as pd
import re

# %%
# import the 'horror movies' csv
df = pd.read_csv("https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2019/2019-10-22/horror_movies.csv")

# %%
df.head(4)
# Out:
#                                  title                    genres release_date  \
# 0                           Gut (2012)   Drama| Horror| Thriller    26-Oct-12
# 1      The Haunting of Mia Moss (2017)                    Horror    13-Jan-17
# 2                  Sleepwalking (2017)                    Horror    21-Oct-17
# 3  Treasure Chest of Horrors II (2013)  Comedy| Horror| Thriller    23-Apr-13
#
#   release_country movie_rating  review_rating movie_run_time  \
# 0             USA          NaN            3.9         91 min
# 1             USA          NaN            NaN            NaN
# 2          Canada          NaN            NaN            NaN
# 3             USA    NOT RATED            3.7         82 min
#
#                                                 plot  \
# 0  Directed by Elias. With Jason Vail, Nicholas W...
# 1  Directed by Jake Zelch. With Nicola Fiore, Bri...
# 2  Directed by David Briggs. With Alysia Topol, A...
# ...

# %%
# remove rows without a listed budget
df = df.dropna(subset=['budget'])

# reset index
df = df.reset_index(drop=True)

df.tail(4)
# Out:
#                                    title                              genres  \
# 1230                    The Purge (2013)            Horror| Sci-Fi| Thriller
# 1231                      13 Sins (2014)                    Horror| Thriller
# 1232          Victor Frankenstein (2015)     Drama| Horror| Sci-Fi| Thriller
# 1233  BloodRayne: The Third Reich (2011)  Action| Adventure| Fantasy| Horror
#
#      release_date release_country movie_rating  review_rating movie_run_time  \
# 1230     7-Jun-13             USA            R            5.7         85 min
# 1231    11-Apr-14          Poland            R            6.3         93 min
# 1232    25-Nov-15             USA        PG-13            6.0        110 min
# 1233    17-Mar-12           Japan            R            3.0         79 min
#
#                                                    plot  \
# 1230  Directed by James DeMonaco. With Ethan Hawke, ...
# 1231  Directed by Daniel Stamm. With Mark Webber, De...
# ...

# %%
# convert release_date column to datetime
df['release_date'] = pd.to_datetime(df['release_date'], dayfirst=True)

df.tail(4)
# Out:
#                                    title                              genres  \
# 1230                    The Purge (2013)            Horror| Sci-Fi| Thriller
# 1231                      13 Sins (2014)                    Horror| Thriller
# 1232          Victor Frankenstein (2015)     Drama| Horror| Sci-Fi| Thriller
# 1233  BloodRayne: The Third Reich (2011)  Action| Adventure| Fantasy| Horror
#
#      release_date release_country movie_rating  review_rating movie_run_time  \
# 1230   2013-06-07             USA            R            5.7         85 min
# 1231   2014-04-11          Poland            R            6.3         93 min
# 1232   2015-11-25             USA        PG-13            6.0        110 min
# 1233   2012-03-17           Japan            R            3.0         79 min
#
#                                                    plot  \
# 1230  Directed by James DeMonaco. With Ethan Hawke, ...
# 1231  Directed by Daniel Stamm. With Mark Webber, De...
# ...
