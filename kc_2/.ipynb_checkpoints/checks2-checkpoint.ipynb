# %%
# Import modules
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read csv
price_csv = pd.read_csv('data.csv')

# %%
# Create line graph for heartwood
price_csv.plot(x = 'Date', y = 'Heartwood')
# Out:
# <AxesSubplot:xlabel='Date'>
